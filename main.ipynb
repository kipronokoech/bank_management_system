# %%
#Calling the bank_account class on bank.py
from bank import bank_account
bank_account = bank_account()

print(70 * "#")
print("\n")
print(20 * " ", "AIMS Bank and Exchange Centre", 10 * " ")
print(30 * " ", "WELCOME!!!", 15 * " ")
print(8 * " ", "brought to you by KIPRONO ELIJAH KOECH(kiprono@aims.ac.za)")
# print(10 * " ", "and SAUMU ABDALLAH ATHMAN KOECH(saumu@aims.ac.za)")
print("\n")
print(70 * "#")
bank_account.services_offered()
while True:
    option = int(input("Select the service: "))
    print(20 * "_")
    if option == 0:
        bank_account.open_account()
        print(50 * "#")
        bank_account.services_offered()
    elif option == 1:
        bank_account.deposit()
        print(50 * "#")
        bank_account.services_offered()
    elif option == 2:
        bank_account.withdraw()
        print(50 * "#")
        bank_account.services_offered()
    elif option == 3:
        bank_account.bal()
        print(50 * "#")
        bank_account.services_offered()
    elif option == 4:
        bank_account.display_all()
        print(50 * "#")
        bank_account.services_offered()
    elif option == 5:
        bank_account.display_ac()
        print(50 * "#")
        bank_account.services_offered()
    elif option == 6:
        bank_account.clear_account()
        print(50 * "#")
        bank_account.services_offered()
    elif option == 7:
        bank_account.close_account()
        print(50 * "#")
        bank_account.services_offered()
    elif option == 8:
        bank_account.currency_conversion()
        print(50 * "#")
        bank_account.services_offered()
    elif option == 9:
        print(50 * "*")
        print(5 * "*", "Thank you for banking with us.", 12 * "*")
        print(50 * "*")
        break
    else:
        # Give an invalid selection alert and allow the user to input the selection again.
        print("Invalid selection")
        print(50 * "#")
# Out:
# https://www.xe.com/currencytables/?from=ZAR&date=2022-01-05
# Date out of range. Using the rates from yesterday.
# Index(['Currency', 'Name', 'Units per ZAR', 'ZAR per unit'], dtype='object')
#     Currency               Name  Units per ZAR   ZAR per unit
# 0        USD          US Dollar       0.063137      15.838516
# 1        EUR               Euro       0.055928      17.880018
# 2        GBP      British Pound       0.046883      21.329686
# 3        INR       Indian Rupee       4.697385       0.212884
# 4        AUD  Australian Dollar       0.087749      11.396083
# ..       ...                ...            ...            ...
# 167      CLF                CLF       0.001951     512.603166
# 168      CNH                CNH       0.402385       2.485181
# 169      MXV                MXV       0.189527       5.276303
# 170      VED                VED       0.289650       3.452443
# 171      XBT            Bitcoin       0.000001  736325.822047
#
# [172 rows x 4 columns]
# ######################################################################
#
#
#                      AIMS Bank and Exchange Centre
#                                WELCOME!!!
#          brought to you by KIPRONO ELIJAH KOECH(kiprono@aims.ac.za)
#
#
# ######################################################################
# ******************************
#        SERVICES OFFERED
# ******************************
# 0: Open account
# 1: Deposit
# 2: Withdraw
# 3: Check balance
# 4: Display all accounts
# 5: Search for an account
# 6: Clear an account (Withdraw all the amount and set account bal to 0)
# 7: Close an account (Withdraw all the amount and delete account)
# 8: Currency Conversion
# 9: Quit
# ____________________
# Your account number is 1402
# ------------------------------------------------------------
# MAKE YOUR FIRST DEPOSIT
# ------------------------------------------------------------
# SELECT THE CURRENCY BELOW:
# 1: UGX
# 2: TZ
# 3: ZAR
# 4: KES
# 5: Other(Specify the currency code)
# 6: Not sure of the country code? press 6 to see all the codes.
# The balance is: 123540.42237472582
# Your details have been saved as follows:
#
#
# ############################################################
# 		 1402 Cherotich Caro 123540.42
# ############################################################
# ##################################################
# ******************************
#        SERVICES OFFERED
# ******************************
# 0: Open account
# 1: Deposit
# 2: Withdraw
# 3: Check balance
# 4: Display all accounts
# 5: Search for an account
# 6: Clear an account (Withdraw all the amount and set account bal to 0)
# 7: Close an account (Withdraw all the amount and delete account)
# 8: Currency Conversion
# 9: Quit
# ____________________
# Your account number is 1403
# ------------------------------------------------------------
# MAKE YOUR FIRST DEPOSIT
# ------------------------------------------------------------
# SELECT THE CURRENCY BELOW:
# 1: UGX
# 2: TZ
# 3: ZAR
# 4: KES
# 5: Other(Specify the currency code)
# 6: Not sure of the country code? press 6 to see all the codes.
# The selected currency is not available. Please try again.
# SELECT THE CURRENCY BELOW:
# 1: UGX
# 2: TZ
# 3: ZAR
# 4: KES
# 5: Other(Specify the currency code)
# 6: Not sure of the country code? press 6 to see all the codes.
# {
#    "USD": "US Dollar",
#    "EUR": "Euro",
#    "GBP": "British Pound",
#    "INR": "Indian Rupee",
#    "AUD": "Australian Dollar",
#    "CAD": "Canadian Dollar",
#    "SGD": "Singapore Dollar",
#    "CHF": "Swiss Franc",
#    "MYR": "Malaysian Ringgit",
#    "JPY": "Japanese Yen",
#    "CNY": "Chinese Yuan Renminbi",
#    "NZD": "New Zealand Dollar",
#    "THB": "Thai Baht",
#    "HUF": "Hungarian Forint",
#    "AED": "Emirati Dirham",
#    "HKD": "Hong Kong Dollar",
#    "MXN": "Mexican Peso",
#    "ZAR": "South African Rand",
#    "PHP": "Philippine Peso",
#    "SEK": "Swedish Krona",
#    "IDR": "Indonesian Rupiah",
#    "BRL": "Brazilian Real",
#    "SAR": "Saudi Arabian Riyal",
#    "TRY": "Turkish Lira",
#    "KES": "Kenyan Shilling",
#    "KRW": "South Korean Won",
#    "EGP": "Egyptian Pound",
#    "IQD": "Iraqi Dinar",
#    "NOK": "Norwegian Krone",
#    "KWD": "Kuwaiti Dinar",
#    "RUB": "Russian Ruble",
#    "DKK": "Danish Krone",
#    "PKR": "Pakistani Rupee",
#    "ILS": "Israeli Shekel",
#    "PLN": "Polish Zloty",
#    "QAR": "Qatari Riyal",
#    "XAU": "Gold Ounce",
#    "OMR": "Omani Rial",
#    "COP": "Colombian Peso",
#    "CLP": "Chilean Peso",
#    "TWD": "Taiwan New Dollar",
#    "ARS": "Argentine Peso",
#    "CZK": "Czech Koruna",
#    "VND": "Vietnamese Dong",
#    "MAD": "Moroccan Dirham",
#    "JOD": "Jordanian Dinar",
#    "BHD": "Bahraini Dinar",
#    "XOF": "CFA Franc",
#    "LKR": "Sri Lankan Rupee",
#    "UAH": "Ukrainian Hryvnia",
#    "NGN": "Nigerian Naira",
#    "TND": "Tunisian Dinar",
#    "UGX": "Ugandan Shilling",
#    "RON": "Romanian Leu",
#    "BDT": "Bangladeshi Taka",
#    "PEN": "Peruvian Sol",
#    "GEL": "Georgian Lari",
#    "XAF": "Central African CFA Franc BEAC",
#    "FJD": "Fijian Dollar",
#    "VEF": "Venezuelan Bol\u00edvar",
#    "VES": "Venezuelan Bol\u00edvar",
#    "BYN": "Belarusian Ruble",
#    "HRK": "Croatian Kuna",
#    "UZS": "Uzbekistani Som",
#    "BGN": "Bulgarian Lev",
#    "DZD": "Algerian Dinar",
#    "IRR": "Iranian Rial",
#    "DOP": "Dominican Peso",
#    "ISK": "Icelandic Krona",
#    "CRC": "Costa Rican Colon",
#    "XAG": "Silver Ounce",
#    "SYP": "Syrian Pound",
#    "JMD": "Jamaican Dollar",
#    "LYD": "Libyan Dinar",
#    "GHS": "Ghanaian Cedi",
#    "MUR": "Mauritian Rupee",
#    "AOA": "Angolan Kwanza",
#    "UYU": "Uruguayan Peso",
#    "AFN": "Afghan Afghani",
#    "LBP": "Lebanese Pound",
#    "XPF": "CFP Franc",
#    "TTD": "Trinidadian Dollar",
#    "TZS": "Tanzanian Shilling",
#    "ALL": "Albanian Lek",
#    "XCD": "East Caribbean Dollar",
#    "GTQ": "Guatemalan Quetzal",
#    "NPR": "Nepalese Rupee",
#    "BOB": "Bolivian Bol\u00edviano",
#    "ZWD": "Zimbabwean Dollar",
#    "BBD": "Barbadian or Bajan Dollar",
#    "CUC": "Cuban Convertible Peso",
#    "LAK": "Lao Kip",
#    "BND": "Bruneian Dollar",
#    "BWP": "Botswana Pula",
#    "HNL": "Honduran Lempira",
#    "PYG": "Paraguayan Guarani",
#    "ETB": "Ethiopian Birr",
#    "NAD": "Namibian Dollar",
#    "PGK": "Papua New Guinean Kina",
#    "SDG": "Sudanese Pound",
#    "MOP": "Macau Pataca",
#    "BMD": "Bermudian Dollar",
#    "NIO": "Nicaraguan Cordoba",
#    "BAM": "Bosnian Convertible Mark",
#    "KZT": "Kazakhstani Tenge",
#    "PAB": "Panamanian Balboa",
#    "GYD": "Guyanese Dollar",
#    "YER": "Yemeni Rial",
#    "MGA": "Malagasy Ariary",
#    "KYD": "Caymanian Dollar",
#    "MZN": "Mozambican Metical",
#    "RSD": "Serbian Dinar",
#    "SCR": "Seychellois Rupee",
#    "AMD": "Armenian Dram",
#    "AZN": "Azerbaijan Manat",
#    "SBD": "Solomon Islander Dollar",
#    "SLL": "Sierra Leonean Leone",
#    "TOP": "Tongan Pa'anga",
#    "BZD": "Belizean Dollar",
#    "GMD": "Gambian Dalasi",
#    "MWK": "Malawian Kwacha",
#    "BIF": "Burundian Franc",
#    "HTG": "Haitian Gourde",
#    "SOS": "Somali Shilling",
#    "GNF": "Guinean Franc",
#    "MNT": "Mongolian Tughrik",
#    "MVR": "Maldivian Rufiyaa",
#    "CDF": "Congolese Franc",
#    "STN": "Sao Tomean Dobra",
#    "TJS": "Tajikistani Somoni",
#    "KPW": "North Korean Won",
#    "KGS": "Kyrgyzstani Som",
#    "LRD": "Liberian Dollar",
#    "LSL": "Basotho Loti",
#    "MMK": "Burmese Kyat",
#    "GIP": "Gibraltar Pound",
#    "XPT": "Platinum Ounce",
#    "MDL": "Moldovan Leu",
#    "CUP": "Cuban Peso",
#    "KHR": "Cambodian Riel",
#    "MKD": "Macedonian Denar",
#    "VUV": "Ni-Vanuatu Vatu",
#    "ANG": "Dutch Guilder",
#    "MRU": "Mauritanian Ouguiya",
#    "SZL": "Swazi Lilangeni",
#    "CVE": "Cape Verdean Escudo",
#    "SRD": "Surinamese Dollar",
#    "SVC": "Salvadoran Colon",
#    "XPD": "Palladium Ounce",
#    "BSD": "Bahamian Dollar",
#    "XDR": "IMF Special Drawing Rights",
#    "RWF": "Rwandan Franc",
#    "AWG": "Aruban or Dutch Guilder",
#    "BTN": "Bhutanese Ngultrum",
#    "DJF": "Djiboutian Franc",
#    "KMF": "Comorian Franc",
#    "ERN": "Eritrean Nakfa",
#    "FKP": "Falkland Island Pound",
#    "SHP": "Saint Helenian Pound",
#    "SPL": "Seborgan Luigino",
#    "WST": "Samoan Tala",
#    "JEP": "Jersey Pound",
#    "TMT": "Turkmenistani Manat",
#    "GGP": "Guernsey Pound",
#    "IMP": "Isle of Man Pound",
#    "TVD": "Tuvaluan Dollar",
#    "ZMW": "Zambian Kwacha",
#    "CLF": "CLF",
#    "CNH": "CNH",
#    "MXV": "MXV",
#    "VED": "VED",
#    "XBT": "Bitcoin"
# }
# {'USD': 'US Dollar', 'EUR': 'Euro', 'GBP': 'British Pound', 'INR': 'Indian Rupee', 'AUD': 'Australian Dollar', 'CAD': 'Canadian Dollar', 'SGD': 'Singapore Dollar', 'CHF': 'Swiss Franc', 'MYR': 'Malaysian Ringgit', 'JPY': 'Japanese Yen', 'CNY': 'Chinese Yuan Renminbi', 'NZD': 'New Zealand Dollar', 'THB': 'Thai Baht', 'HUF': 'Hungarian Forint', 'AED': 'Emirati Dirham', 'HKD': 'Hong Kong Dollar', 'MXN': 'Mexican Peso', 'ZAR': 'South African Rand', 'PHP': 'Philippine Peso', 'SEK': 'Swedish Krona', 'IDR': 'Indonesian Rupiah', 'BRL': 'Brazilian Real', 'SAR': 'Saudi Arabian Riyal', 'TRY': 'Turkish Lira', 'KES': 'Kenyan Shilling', 'KRW': 'South Korean Won', 'EGP': 'Egyptian Pound', 'IQD': 'Iraqi Dinar', 'NOK': 'Norwegian Krone', 'KWD': 'Kuwaiti Dinar', 'RUB': 'Russian Ruble', 'DKK': 'Danish Krone', 'PKR': 'Pakistani Rupee', 'ILS': 'Israeli Shekel', 'PLN': 'Polish Zloty', 'QAR': 'Qatari Riyal', 'XAU': 'Gold Ounce', 'OMR': 'Omani Rial', 'COP': 'Colombian Peso', 'CLP': 'Chilean Peso', 'TWD': 'Taiwan New Dollar', 'ARS': 'Argentine Peso', 'CZK': 'Czech Koruna', 'VND': 'Vietnamese Dong', 'MAD': 'Moroccan Dirham', 'JOD': 'Jordanian Dinar', 'BHD': 'Bahraini Dinar', 'XOF': 'CFA Franc', 'LKR': 'Sri Lankan Rupee', 'UAH': 'Ukrainian Hryvnia', 'NGN': 'Nigerian Naira', 'TND': 'Tunisian Dinar', 'UGX': 'Ugandan Shilling', 'RON': 'Romanian Leu', 'BDT': 'Bangladeshi Taka', 'PEN': 'Peruvian Sol', 'GEL': 'Georgian Lari', 'XAF': 'Central African CFA Franc BEAC', 'FJD': 'Fijian Dollar', 'VEF': 'Venezuelan Bolívar', 'VES': 'Venezuelan Bolívar', 'BYN': 'Belarusian Ruble', 'HRK': 'Croatian Kuna', 'UZS': 'Uzbekistani Som', 'BGN': 'Bulgarian Lev', 'DZD': 'Algerian Dinar', 'IRR': 'Iranian Rial', 'DOP': 'Dominican Peso', 'ISK': 'Icelandic Krona', 'CRC': 'Costa Rican Colon', 'XAG': 'Silver Ounce', 'SYP': 'Syrian Pound', 'JMD': 'Jamaican Dollar', 'LYD': 'Libyan Dinar', 'GHS': 'Ghanaian Cedi', 'MUR': 'Mauritian Rupee', 'AOA': 'Angolan Kwanza', 'UYU': 'Uruguayan Peso', 'AFN': 'Afghan Afghani', 'LBP': 'Lebanese Pound', 'XPF': 'CFP Franc', 'TTD': 'Trinidadian Dollar', 'TZS': 'Tanzanian Shilling', 'ALL': 'Albanian Lek', 'XCD': 'East Caribbean Dollar', 'GTQ': 'Guatemalan Quetzal', 'NPR': 'Nepalese Rupee', 'BOB': 'Bolivian Bolíviano', 'ZWD': 'Zimbabwean Dollar', 'BBD': 'Barbadian or Bajan Dollar', 'CUC': 'Cuban Convertible Peso', 'LAK': 'Lao Kip', 'BND': 'Bruneian Dollar', 'BWP': 'Botswana Pula', 'HNL': 'Honduran Lempira', 'PYG': 'Paraguayan Guarani', 'ETB': 'Ethiopian Birr', 'NAD': 'Namibian Dollar', 'PGK': 'Papua New Guinean Kina', 'SDG': 'Sudanese Pound', 'MOP': 'Macau Pataca', 'BMD': 'Bermudian Dollar', 'NIO': 'Nicaraguan Cordoba', 'BAM': 'Bosnian Convertible Mark', 'KZT': 'Kazakhstani Tenge', 'PAB': 'Panamanian Balboa', 'GYD': 'Guyanese Dollar', 'YER': 'Yemeni Rial', 'MGA': 'Malagasy Ariary', 'KYD': 'Caymanian Dollar', 'MZN': 'Mozambican Metical', 'RSD': 'Serbian Dinar', 'SCR': 'Seychellois Rupee', 'AMD': 'Armenian Dram', 'AZN': 'Azerbaijan Manat', 'SBD': 'Solomon Islander Dollar', 'SLL': 'Sierra Leonean Leone', 'TOP': "Tongan Pa'anga", 'BZD': 'Belizean Dollar', 'GMD': 'Gambian Dalasi', 'MWK': 'Malawian Kwacha', 'BIF': 'Burundian Franc', 'HTG': 'Haitian Gourde', 'SOS': 'Somali Shilling', 'GNF': 'Guinean Franc', 'MNT': 'Mongolian Tughrik', 'MVR': 'Maldivian Rufiyaa', 'CDF': 'Congolese Franc', 'STN': 'Sao Tomean Dobra', 'TJS': 'Tajikistani Somoni', 'KPW': 'North Korean Won', 'KGS': 'Kyrgyzstani Som', 'LRD': 'Liberian Dollar', 'LSL': 'Basotho Loti', 'MMK': 'Burmese Kyat', 'GIP': 'Gibraltar Pound', 'XPT': 'Platinum Ounce', 'MDL': 'Moldovan Leu', 'CUP': 'Cuban Peso', 'KHR': 'Cambodian Riel', 'MKD': 'Macedonian Denar', 'VUV': 'Ni-Vanuatu Vatu', 'ANG': 'Dutch Guilder', 'MRU': 'Mauritanian Ouguiya', 'SZL': 'Swazi Lilangeni', 'CVE': 'Cape Verdean Escudo', 'SRD': 'Surinamese Dollar', 'SVC': 'Salvadoran Colon', 'XPD': 'Palladium Ounce', 'BSD': 'Bahamian Dollar', 'XDR': 'IMF Special Drawing Rights', 'RWF': 'Rwandan Franc', 'AWG': 'Aruban or Dutch Guilder', 'BTN': 'Bhutanese Ngul ...
# ####################
# ####################
# The balance is: 416536.653868377
# Your details have been saved as follows:
#
#
# ############################################################
# 		 1403 Adams 4 416536.65
# ############################################################
# ##################################################
# ******************************
#        SERVICES OFFERED
# ******************************
# 0: Open account
# 1: Deposit
# 2: Withdraw
# 3: Check balance
# 4: Display all accounts
# 5: Search for an account
# 6: Clear an account (Withdraw all the amount and set account bal to 0)
# 7: Close an account (Withdraw all the amount and delete account)
# 8: Currency Conversion
# 9: Quit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_16161/2927775231.py in <module>
#      13 bank_account.services_offered()
#      14 while True:
# ---> 15     option = int(input("Select the service: "))
#      16     print(20 * "_")
#      17     if option == 0:
#
# ValueError: invalid literal for int() with base 10: ''
